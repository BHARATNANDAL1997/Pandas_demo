# %% [markdown]
# <a href="https://colab.research.google.com/github/BHARATNANDAL1997/Pandas_demo/blob/main/Python_basics_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Universities.csv')
print(df)
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df['SAT'])
plt.xlabel('SAT')
plt.title('Histogram of SAT')
plt.show()

# %%
import seaborn as sns
sns.histplot(df['Accept'])
#plt.show()
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(df['Expenses'])
#plt.show()
# Out:
# <Axes: xlabel='Expenses', ylabel='Count'>

# %%
plt.plot(df['SAT'],df['Accept'],'bo')
plt.xla bel('SAT')
plt.ylabel('Accept')
plt.title('Scatterplot between SAT vs Accept')
# Out:
#   Cell In[27], line 2
#     plt.xla bel('SAT')
#             ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(df)

# %%
plt.boxplot(df['SAT'])
plt.show()

# %%
sns.pairplot(df.iloc[:,1:4])

# %%
plt.boxplot(df['SAT'])
plt.show( )

# %%
plt.boxplot(df['Top10'])
plt.show()

# %%
plt.boxplot(df['Accept'])
plt.xlabel('Accept')
plt.ylabel('Values')
plt.title('boxplot for Accept')
plt.show()

# %%
plt.boxplot(df['Accept'], vert = False)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['SAT'])

# %%
sns.distplot(df['Accept '])

# %%
dup = pd.deataframe({'col1':['A','B','A','B']}),'col2':[1,2,1,2]})

# %%
dep.[dep.duplicated()]

# %%
Numpy Arrays

# %%
import numpy as np
a= np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (2, 4)

# %%
print(a.size)
# Out:
# 8

# %%
a= a.reshape(4,2)

# %%
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [4 5]
#  [6 7]]

# %%
a.shape
# Out:
# (4, 2)

# %%
a = np.array([1,2,3,4])

# %%
a.shape
# Out:
# (4,)

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
a.mean()
# Out:
# 2.5

# %%
a.sum()
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
a[0]
# Out:
# 1

# %%
a[1]
# Out:
# 2

# %%
a[3]
# Out:
# 4

# %%
a[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 a[4]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
a = np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
a[0,1]
# Out:
# 2

# %%
a[1,1]
# Out:
# 5

# %%
a.sum(axis = 0)
# Out:
# array([ 5,  7,  9, 11])

# %%
a.sum(axis = 1)
# Out:
# array([10, 22])
